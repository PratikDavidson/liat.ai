# %%
from ultralytics import YOLO

# %%
model = YOLO("models/best.pt")

# %%
model.names
# Out:
# {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}

# %%
results = model.track(
            source="data/15sec_input_720p.mp4",
            conf=0.8,
            iou=0.95,
            persist=True, 
            classes=[1, 2], 
            half=True, 
            device=0, 
        )
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/375) c:\Users\mckni\temp_repo\liat.ai\data\15sec_input_720p.mp4: 384x640 24 players, 125.1ms
# video 1/1 (frame 2/375) c:\Users\mckni\temp_repo\liat.ai\data\15sec_input_720p.mp4: 384x640 17 players, 21.3ms
# video 1/1 (frame 3/375) c:\Users\mckni\temp_repo\liat.ai\data\15sec_input_720p.mp4: 384x640 16 players, 20.5ms
# ...
